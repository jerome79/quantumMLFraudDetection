# %% [markdown]
# # Exploratory Data Analysis
# # ULB Credit Card Fraud Detection Dataset
#
# This notebook provides exploratory analysis of the credit card fraud detection dataset.

# %%
import sys
sys.path.append('..')
# python
import importlib
from src import config
importlib.reload(config)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_creditcard_data
from src.utils import print_dataset_info

# %matplotlib inline

# %%
import sys
import importlib
print("First matching config on sys.path:")
import pkgutil
print([m.module_finder.path for m in pkgutil.iter_modules() if m.name == "config"][:3])

from src import config
print("Loaded module file:", config.__file__)
print("Has DATA_PATH?", hasattr(config, "DATA_PATH"))
if not hasattr(config, "DATA_PATH"):
    importlib.reload(config)
    print("After reload, has DATA_PATH?", hasattr(config, "DATA_PATH"))
else:
    print("DATA_PATH value:", config.DATA_PATH)
# Out:
# First matching config on sys.path:
# []
# Loaded module file: C:\Users\jerom\PycharmProjects\quantumMLFraudDetection\src\config.py
# Has DATA_PATH? True
# DATA_PATH value: C:\Users\jerom\PycharmProjects\quantumMLFraudDetection\data\raw\creditcard.csv

# %% [markdown]
# ## 1. Load Data

# %%
# Load the dataset
df = load_creditcard_data()
print_dataset_info(df)
# Out:
# Loaded dataset with shape: (284807, 31)
# Fraud cases: 492 (0.17%)
#
# Dataset Information:
# ----------------------------------------
# Shape: (284807, 31)
# Columns: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
#
# Data types:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# ...

# %% [markdown]
# ## 2. Class Distribution

# %%
# Visualize class distribution
plt.figure(figsize=(8, 6))
df['Class'].value_counts().plot(kind='bar')
plt.xlabel('Class (0=Non-Fraud, 1=Fraud)')
plt.ylabel('Count')
plt.title('Distribution of Fraud vs Non-Fraud Transactions')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 3. Feature Analysis

# %%
# Display first few rows
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## 4. Statistical Summary

# %%
# Statistical summary
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %% [markdown]
# ## 5. Correlation Analysis

# %%
# Compute correlation with target
correlations = df.corr()['Class'].sort_values(ascending=False)
print("Top 10 features correlated with fraud:")
print(correlations.head(10))
# Out:
# Top 10 features correlated with fraud:
# Class    1.000000
# V11      0.154876
# V4       0.133447
# V2       0.091289
# V21      0.040413
# V19      0.034783
# V20      0.020090
# V8       0.019875
# V27      0.017580
# V28      0.009536
# Name: Class, dtype: float64

# %% [markdown]
# ## 6. Additional Analysis
#
# Add your own exploratory analysis here...
